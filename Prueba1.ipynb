# %% [markdown]
# #

# %%
import numpy as np
import numpy.ma as ma
import pandas as pd
import math as m

import mib as mb
from conteoJugadaPorPalabra import t1, t2, t3, t4

# %%
tablaT1 = mb.Var('t1', list(t1.keys()))       
Pt1 = mb.Distrib('P(t1)', [tablaT1], t1)
tablaT2 = mb.Var('t2', list(t2.keys()))       
Pt2 = mb.Distrib('P(t2)', [tablaT2], t2)
tablaT3 = mb.Var('t3', list(t3.keys()))       
Pt3 = mb.Distrib('P(t3)', [tablaT3], t3)
tablaT4 = mb.Var('t4', list(t4.keys()))       
Pt4 = mb.Distrib('P(t4)', [tablaT4], t4)

# %%
Pt1._print()
# Out:
# Printing:  P(t1)
# ...
